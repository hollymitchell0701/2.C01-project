# %%
from matplotlib import pyplot as plt
import fastf1
import fastf1.plotting
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
fastf1.plotting.setup_mpl()
session = fastf1.get_session(2019, 7, 'Q')
# Out:
# /Users/hollymitchell/miniconda3/envs/mlpack_clean/lib/python3.10/site-packages/fastf1/plotting/_plotting.py:90: FutureWarning: FastF1 will no longer silently modify the default Matplotlib colors in the future.
# To remove this warning, explicitly set `color_scheme=None` or `color_scheme='fastf1'` when calling `.setup_mpl()`.
#   warnings.warn(
# /Users/hollymitchell/miniconda3/envs/mlpack_clean/lib/python3.10/site-packages/fastf1/plotting/_plotting.py:98: FutureWarning: FastF1 will stop modifying the default Matplotlib settings in the future.
# To opt-in to the new behaviour and remove this warning, explicitly set `misc_mpl_mods=False` when calling `.setup_mpl()`.
#   warnings.warn(
# req         WARNING 	DEFAULT CACHE ENABLED! (6.64 GB) /Users/hollymitchell/Library/Caches/fastf1

# %% [markdown]
# ### Explore Session

# %%
session.date
# Out:
# Timestamp('2019-06-08 18:00:00')

# %%
session.name
# Out:
# 'Qualifying'

# %%
session.event
# Out:
# RoundNumber                                                    7
# Country                                                   Canada
# Location                                                Montréal
# OfficialEventName    FORMULA 1 PIRELLI GRAND PRIX DU CANADA 2019
# EventDate                                    2019-06-09 00:00:00
# EventName                                    Canadian Grand Prix
# EventFormat                                         conventional
# Session1                                              Practice 1
# Session1Date                           2019-06-07 10:00:00-04:00
# Session1DateUtc                              2019-06-07 14:00:00
# Session2                                              Practice 2
# Session2Date                           2019-06-07 14:00:00-04:00
# Session2DateUtc                              2019-06-07 18:00:00
# Session3                                              Practice 3
# ...

# %%
session.load()
session.results
# Out:
# core           INFO 	Loading data for Canadian Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver 16: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['5', '44', '16', '3', '10', '77', '27', '4', '55', '20', '33', '26', '99', '23', '8', '11', '7', '18', '63', '88']
# ...

# %%
session.laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 00:21:21.057000    VET            5 0 days 00:01:35.117000
# 1   0 days 00:22:33.396000    VET            5 0 days 00:01:12.339000
# 2   0 days 00:24:07.874000    VET            5 0 days 00:01:34.478000
# 3   0 days 00:25:19.475000    VET            5 0 days 00:01:11.601000
# 4   0 days 00:26:55.614000    VET            5 0 days 00:01:36.139000
# ..                     ...    ...          ...                    ...
# 312 0 days 00:29:05.362000    KUB           88 0 days 00:01:28.975000
# 313 0 days 00:30:19.755000    KUB           88 0 days 00:01:14.393000
# 314 0 days 00:31:58.895000    KUB           88 0 days 00:01:39.140000
# 315 0 days 00:33:13.840000    KUB           88 0 days 00:01:14.945000
# 316 0 days 00:34:37.471000    KUB           88                    NaT
#
#      LapNumber  Stint             PitOutTime              PitInTime  \
# ...

# %%
session.laps.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
# plot distribution of laptimes
plt.figure(figsize=(10, 5))
plt.hist(session.laps['LapTime'].dt.total_seconds(), bins=50)
plt.xlabel('Lap Time (s)')
plt.ylabel('Count')
plt.title('Lap Time Distribution')
plt.grid()

# %%
session.laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 00:21:21.057000    VET            5 0 days 00:01:35.117000
# 1   0 days 00:22:33.396000    VET            5 0 days 00:01:12.339000
# 2   0 days 00:24:07.874000    VET            5 0 days 00:01:34.478000
# 3   0 days 00:25:19.475000    VET            5 0 days 00:01:11.601000
# 4   0 days 00:26:55.614000    VET            5 0 days 00:01:36.139000
# ..                     ...    ...          ...                    ...
# 312 0 days 00:29:05.362000    KUB           88 0 days 00:01:28.975000
# 313 0 days 00:30:19.755000    KUB           88 0 days 00:01:14.393000
# 314 0 days 00:31:58.895000    KUB           88 0 days 00:01:39.140000
# 315 0 days 00:33:13.840000    KUB           88 0 days 00:01:14.945000
# 316 0 days 00:34:37.471000    KUB           88                    NaT
#
#      LapNumber  Stint             PitOutTime              PitInTime  \
# ...

# %%
session.laps.get_weather_data()
# Out:
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 19 0 days 00:19:51.223000     21.7      23.6    1022.3     False       47.7
# 21 0 days 00:21:51.249000     21.8      23.7    1022.3     False       47.8
# 22 0 days 00:22:51.261000     21.9      25.7    1022.4     False       47.8
# 24 0 days 00:24:51.287000     22.4      23.2    1022.3     False       47.8
# 25 0 days 00:25:51.300000     22.5      25.4    1022.3     False       47.8
# ..                    ...      ...       ...       ...       ...        ...
# 27 0 days 00:27:51.326000     22.6      24.6    1022.2     False       47.3
# 29 0 days 00:29:51.368000     22.3      22.1    1022.2     False       47.7
# 30 0 days 00:30:51.365000     22.2      21.5    1022.1     False       47.7
# 32 0 days 00:32:51.407000     22.2      25.0    1022.2     False       47.9
# 33 0 days 00:33:51.420000     22.6      24.0    1022.1     False       47.9
#
#     WindDirection  WindSpeed
# ...

# %%
# obtain weather data for each lap for each driver in the session
weather_data = session.laps.get_weather_data()
# filter out laps with missing weather data

# %%
session.weather_data
# Out:
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0  0 days 00:00:50.944000     21.5      22.3    1022.5     False       45.5
# 1  0 days 00:01:50.957000     21.8      22.8    1022.4     False       45.5
# 2  0 days 00:02:50.970000     21.6      22.3    1022.5     False       46.1
# 3  0 days 00:03:50.999000     21.8      23.5    1022.4     False       46.4
# 4  0 days 00:04:51.012000     22.0      23.0    1022.4     False       46.5
# ..                    ...      ...       ...       ...       ...        ...
# 89 0 days 01:29:52.196000     23.2      20.8    1021.8     False       48.2
# 90 0 days 01:30:52.209000     23.1      21.1    1021.8     False       48.2
# 91 0 days 01:31:52.237000     23.4      20.9    1021.8     False       48.4
# 92 0 days 01:32:52.235000     23.5      21.6    1021.8     False       48.4
# 93 0 days 01:33:52.263000     23.3      21.5    1021.7     False       48.3
#
#     WindDirection  WindSpeed
# ...

# %%
session.car_data
# Out:
# {'5':                          Date  RPM  Speed  nGear  Throttle  Brake  DRS Source  \
#  0     2019-06-08 17:45:03.228  0.0    0.0      0       0.0  False    0    car
#  1     2019-06-08 17:45:03.468  0.0    0.0      0       0.0  False    0    car
#  2     2019-06-08 17:45:03.707  0.0    0.0      0       0.0  False    0    car
#  3     2019-06-08 17:45:03.987  0.0    0.0      0       0.0  False    0    car
#  4     2019-06-08 17:45:04.227  0.0    0.0      0       0.0  False    0    car
#  ...                       ...  ...    ...    ...       ...    ...  ...    ...
#  23379 2019-06-08 19:19:41.567  0.0    0.0      0       0.0  False    8    car
#  23380 2019-06-08 19:19:41.807  0.0    0.0      0       0.0  False    8    car
#  23381 2019-06-08 19:19:42.047  0.0    0.0      0       0.0  False    8    car
#  23382 2019-06-08 19:19:42.287  0.0    0.0      0       0.0  False    8    car
#  23383 2019-06-08 19:19:42.527  0.0    0.0      0       0.0  False    8    car
#
# ...

# %%
session.car_data['33'].head()
# Out:
#                      Date  RPM  Speed  nGear  Throttle  Brake  DRS Source  \
# 0 2019-06-08 17:45:03.228  0.0    0.0      0       0.0  False    8    car
# 1 2019-06-08 17:45:03.468  0.0    0.0      0       0.0  False    8    car
# 2 2019-06-08 17:45:03.707  0.0    0.0      0       0.0  False    8    car
# 3 2019-06-08 17:45:03.987  0.0    0.0      0       0.0  False    8    car
# 4 2019-06-08 17:45:04.227  0.0    0.0      0       0.0  False    8    car
#
#                     Time            SessionTime
# 0 0 days 00:00:03.163000 0 days 00:00:03.163000
# 1 0 days 00:00:03.403000 0 days 00:00:03.403000
# 2 0 days 00:00:03.642000 0 days 00:00:03.642000
# 3 0 days 00:00:03.922000 0 days 00:00:03.922000
# 4 0 days 00:00:04.162000 0 days 00:00:04.162000

# %%
session.car_data['33'].columns
# Out:
# Index(['Date', 'RPM', 'Speed', 'nGear', 'Throttle', 'Brake', 'DRS', 'Source',
#        'Time', 'SessionTime'],
#       dtype='object')

# %%
session.weather_data
# Out:
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0  0 days 00:00:50.944000     21.5      22.3    1022.5     False       45.5
# 1  0 days 00:01:50.957000     21.8      22.8    1022.4     False       45.5
# 2  0 days 00:02:50.970000     21.6      22.3    1022.5     False       46.1
# 3  0 days 00:03:50.999000     21.8      23.5    1022.4     False       46.4
# 4  0 days 00:04:51.012000     22.0      23.0    1022.4     False       46.5
# ..                    ...      ...       ...       ...       ...        ...
# 89 0 days 01:29:52.196000     23.2      20.8    1021.8     False       48.2
# 90 0 days 01:30:52.209000     23.1      21.1    1021.8     False       48.2
# 91 0 days 01:31:52.237000     23.4      20.9    1021.8     False       48.4
# 92 0 days 01:32:52.235000     23.5      21.6    1021.8     False       48.4
# 93 0 days 01:33:52.263000     23.3      21.5    1021.7     False       48.3
#
#     WindDirection  WindSpeed
# ...

# %%
session.track_status
# Out:
#                     Time Status   Message
# 0        0 days 00:00:00      1  AllClear
# 1 0 days 00:55:04.829000      2    Yellow
# 2 0 days 00:55:11.428000      5       Red
# 3 0 days 01:15:11.657000      1  AllClear
# 4 0 days 01:15:57.115000      2    Yellow
# 5 0 days 01:16:33.525000      1  AllClear
# 6 0 days 01:23:44.474000      2    Yellow
# 7 0 days 01:23:55.253000      1  AllClear
# 8 0 days 01:23:55.706000      2    Yellow
# 9 0 days 01:24:00.323000      1  AllClear

# %%
# merge all the session.laps with the seassion.weather_data with StartLapTime to the closest Time in weather data

# copy session laps
laps = session.laps.copy()

for i, lap in laps.iterrows():
    # find the closest weather data point to the lap start time
    closest_weather = session.weather_data.iloc[(session.weather_data['Time'] - lap['LapStartTime']).abs().argmin()]
    # assign the weather data to the lap
    laps.at[i, 'AirTemp'] = closest_weather['AirTemp']
laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 00:21:21.057000    VET            5 0 days 00:01:35.117000
# 1   0 days 00:22:33.396000    VET            5 0 days 00:01:12.339000
# 2   0 days 00:24:07.874000    VET            5 0 days 00:01:34.478000
# 3   0 days 00:25:19.475000    VET            5 0 days 00:01:11.601000
# 4   0 days 00:26:55.614000    VET            5 0 days 00:01:36.139000
# ..                     ...    ...          ...                    ...
# 312 0 days 00:29:05.362000    KUB           88 0 days 00:01:28.975000
# 313 0 days 00:30:19.755000    KUB           88 0 days 00:01:14.393000
# 314 0 days 00:31:58.895000    KUB           88 0 days 00:01:39.140000
# 315 0 days 00:33:13.840000    KUB           88 0 days 00:01:14.945000
# 316 0 days 00:34:37.471000    KUB           88                    NaT
#
#      LapNumber  Stint             PitOutTime              PitInTime  \
# ...

# %%
# plot air temperature vs lap time
plt.figure(figsize=(10, 5))
plt.scatter(laps['AirTemp'], laps['LapTime'].dt.total_seconds())
plt.xlabel('Air Temperature (C)')
plt.ylabel('Lap Time (s)')
plt.title('Lap Time vs Air Temperature')
plt.grid()
plt.show()

# %%
# add session info to the laps dataframe
laps['SessionName'] = session.name
laps['SessionDate'] = session.date
laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 00:21:21.057000    VET            5 0 days 00:01:35.117000
# 1   0 days 00:22:33.396000    VET            5 0 days 00:01:12.339000
# 2   0 days 00:24:07.874000    VET            5 0 days 00:01:34.478000
# 3   0 days 00:25:19.475000    VET            5 0 days 00:01:11.601000
# 4   0 days 00:26:55.614000    VET            5 0 days 00:01:36.139000
# ..                     ...    ...          ...                    ...
# 312 0 days 00:29:05.362000    KUB           88 0 days 00:01:28.975000
# 313 0 days 00:30:19.755000    KUB           88 0 days 00:01:14.393000
# 314 0 days 00:31:58.895000    KUB           88 0 days 00:01:39.140000
# 315 0 days 00:33:13.840000    KUB           88 0 days 00:01:14.945000
# 316 0 days 00:34:37.471000    KUB           88                    NaT
#
#      LapNumber  Stint             PitOutTime              PitInTime  \
# ...

# %%
# plot distribution of throttle
plt.figure(figsize=(10, 5))
plt.hist(session.car_data['33']['Throttle'], bins=50)
plt.xlabel('Throttle (%)')
plt.ylabel('Count')
plt.title('Throttle Distribution')
plt.grid()

# %%
session.car_data['33']
# Out:
#                          Date  RPM  Speed  nGear  Throttle  Brake  DRS Source  \
# 0     2019-06-08 17:45:03.228  0.0    0.0      0       0.0  False    8    car
# 1     2019-06-08 17:45:03.468  0.0    0.0      0       0.0  False    8    car
# 2     2019-06-08 17:45:03.707  0.0    0.0      0       0.0  False    8    car
# 3     2019-06-08 17:45:03.987  0.0    0.0      0       0.0  False    8    car
# 4     2019-06-08 17:45:04.227  0.0    0.0      0       0.0  False    8    car
# ...                       ...  ...    ...    ...       ...    ...  ...    ...
# 23379 2019-06-08 19:19:41.567  0.0    0.0      0     104.0   True    9    car
# 23380 2019-06-08 19:19:41.807  0.0    0.0      0     104.0   True    9    car
# 23381 2019-06-08 19:19:42.047  0.0    0.0      0     104.0   True    9    car
# 23382 2019-06-08 19:19:42.287  0.0    0.0      0     104.0   True    9    car
# 23383 2019-06-08 19:19:42.527  0.0    0.0      0     104.0   True    9    car
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colormaps
from matplotlib.collections import LineCollection

import fastf1


session = fastf1.get_session(2021, 'Austrian Grand Prix', 'Q')
session.load()

lap = session.laps.pick_fastest()
tel = lap.get_telemetry()
# Out:
# core           INFO 	Loading data for Austrian Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '4', '11', '44', '77', '10', '22', '5', '63', '18', '55', '16', '3', '14', '99', '7', '31', '6', '47', '9']

# %%
type(session)
# Out:
# fastf1.core.Session

# %%
print(session.laps.columns)
session.laps
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 00:20:19.049000    VER           33                    NaT
# 1   0 days 00:21:23.298000    VER           33 0 days 00:01:04.249000
# 2   0 days 00:23:38.646000    VER           33 0 days 00:02:15.348000
# 3   0 days 00:45:58.103000    VER           33                    NaT
# 4   0 days 00:47:02.311000    VER           33 0 days 00:01:04.208000
# ...

# %%
print(session.car_data.keys())
len(session.car_data.keys())
# Out:
# dict_keys(['33', '4', '11', '44', '77', '10', '22', '5', '63', '18', '55', '16', '3', '14', '99', '7', '31', '6', '47', '9'])
# 20

# %%
session.car_data['33'].columns
# Out:
# Index(['Date', 'RPM', 'Speed', 'nGear', 'Throttle', 'Brake', 'DRS', 'Source',
#        'Time', 'SessionTime'],
#       dtype='object')

# %%
session.weather_data.columns
# Out:
# Index(['Time', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp',
#        'WindDirection', 'WindSpeed'],
#       dtype='object')

# %%
session.weather_data
# Out:
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0  0 days 00:00:26.705000     24.9      28.6     936.7     False       49.0
# 1  0 days 00:01:26.706000     25.0      29.0     936.8     False       49.4
# 2  0 days 00:02:26.725000     25.1      28.7     936.6     False       49.7
# 3  0 days 00:03:26.724000     25.2      28.2     936.6     False       50.3
# 4  0 days 00:04:26.723000     25.3      27.6     936.6     False       51.0
# ..                    ...      ...       ...       ...       ...        ...
# 72 0 days 01:12:26.896000     26.1      26.2     936.1     False       51.5
# 73 0 days 01:13:26.894000     25.9      25.6     936.1     False       52.1
# 74 0 days 01:14:26.913000     25.9      26.2     936.1     False       52.1
# 75 0 days 01:15:26.933000     26.2      25.5     936.1     False       51.9
# 76 0 days 01:16:26.934000     26.0      26.8     936.1     False       51.9
#
#     WindDirection  WindSpeed
# ...

# %%
session.race_control_messages
# Out:
#                   Time Category  \
# 0  2021-07-03 12:00:02    Other
# 1  2021-07-03 12:45:02    Other
# 2  2021-07-03 13:00:00     Flag
# 3  2021-07-03 13:06:23    Other
# 4  2021-07-03 13:12:10    Other
# 5  2021-07-03 13:18:00     Flag
# 6  2021-07-03 13:18:18    Other
# 7  2021-07-03 13:18:59    Other
# 8  2021-07-03 13:25:00     Flag
# 9  2021-07-03 13:40:00     Flag
# 10 2021-07-03 13:40:15    Other
# 11 2021-07-03 13:40:27    Other
# 12 2021-07-03 13:41:28    Other
# 13 2021-07-03 13:48:00     Flag
# 14 2021-07-03 14:00:00     Flag
# 15 2021-07-03 14:00:12    Other
# 16 2021-07-03 14:15:02     Flag
# 17 2021-07-03 14:20:01    Other
#
#                                               Message Status       Flag  \
# 0       AIR TEMPERATURE 1 HOUR BEFORE Q1 = 24 DEGREES   None       None
# 1        RISK OF RAIN FOR F1 QUALIFYING SESSION IS 0%   None       None
# 2                         GREEN LIGHT - PIT EXIT OPEN   None      GREEN
# ...

# %%
session.session_status
# Out:
#                      Time     Status
# 0  0 days 00:00:05.126000   Inactive
# 1  0 days 00:14:33.672000    Started
# 2  0 days 00:32:33.688000   Finished
# 3  0 days 00:37:38.440000   Inactive
# 4  0 days 00:39:33.674000    Started
# 5  0 days 00:54:33.708000   Finished
# 6  0 days 01:00:39.035000   Inactive
# 7  0 days 01:02:33.686000    Started
# 8  0 days 01:14:33.801000   Finished
# 9  0 days 01:17:19.244000  Finalised
# 10 0 days 01:34:34.648000       Ends

# %%
session.laps.pick_driver('VER').pick_lap(10).get_telemetry()
# Out:
# /Users/hollymitchell/miniconda3/envs/mlpack_clean/lib/python3.10/site-packages/fastf1/core.py:3067: FutureWarning: pick_driver is deprecated and will be removed in a future release. Use pick_drivers instead.
#   warnings.warn(("pick_driver is deprecated and will be removed"
# /Users/hollymitchell/miniconda3/envs/mlpack_clean/lib/python3.10/site-packages/fastf1/core.py:3021: FutureWarning: pick_lap is deprecated and will be removed in a future release. Use pick_laps instead.
#   warnings.warn(("pick_lap is deprecated and will be removed in a "
#                         Date            SessionTime DriverAhead  \
# 2    2021-07-03 13:41:56.266 0 days 00:56:29.851000
# 3    2021-07-03 13:41:56.461 0 days 00:56:30.046000
# 4    2021-07-03 13:41:56.498 0 days 00:56:30.083000
# 5    2021-07-03 13:41:56.681 0 days 00:56:30.266000
# 6    2021-07-03 13:41:56.738 0 days 00:56:30.323000           4
# ...                      ...                    ...         ...
# ...

# %%
laps = session.laps.copy()
# get the weather data for each lap
weather_data = session.laps.get_weather_data()
laps = laps.reset_index(drop=True)
weather_data = weather_data.reset_index(drop=True)

# exclude the 'Time' column from weather data when joining
joined = pd.concat([laps, weather_data.loc[:, ~(weather_data.columns == 'Time')]], axis=1)
print(joined)
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 00:20:19.049000    VER           33                    NaT
# 1   0 days 00:21:23.298000    VER           33 0 days 00:01:04.249000
# 2   0 days 00:23:38.646000    VER           33 0 days 00:02:15.348000
# 3   0 days 00:45:58.103000    VER           33                    NaT
# 4   0 days 00:47:02.311000    VER           33 0 days 00:01:04.208000
# ..                     ...    ...          ...                    ...
# 294 0 days 00:24:58.675000    MAZ            9 0 days 00:01:06.282000
# 295 0 days 00:26:52.290000    MAZ            9 0 days 00:01:53.615000
# 296 0 days 00:31:17.977000    MAZ            9                    NaT
# 297 0 days 00:32:23.928000    MAZ            9 0 days 00:01:05.951000
# 298 0 days 00:33:46.850000    MAZ            9 0 days 00:01:22.922000
#
#      LapNumber  Stint             PitOutTime              PitInTime  \
# ...

# %%
joined
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 00:20:19.049000    VER           33                    NaT
# 1   0 days 00:21:23.298000    VER           33 0 days 00:01:04.249000
# 2   0 days 00:23:38.646000    VER           33 0 days 00:02:15.348000
# 3   0 days 00:45:58.103000    VER           33                    NaT
# 4   0 days 00:47:02.311000    VER           33 0 days 00:01:04.208000
# ..                     ...    ...          ...                    ...
# 294 0 days 00:24:58.675000    MAZ            9 0 days 00:01:06.282000
# 295 0 days 00:26:52.290000    MAZ            9 0 days 00:01:53.615000
# 296 0 days 00:31:17.977000    MAZ            9                    NaT
# 297 0 days 00:32:23.928000    MAZ            9 0 days 00:01:05.951000
# 298 0 days 00:33:46.850000    MAZ            9 0 days 00:01:22.922000
#
#      LapNumber  Stint             PitOutTime              PitInTime  \
# ...

# %%
joined.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate', 'AirTemp', 'Humidity', 'Pressure',
#        'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed'],
#       dtype='object')

# %%
# remove laps where pitouttime or pitintime is not NaT (keep undefined laps)

clean_laps = joined.copy()
clean_laps = clean_laps[(clean_laps['PitOutTime'].isna()) & (clean_laps['PitInTime'].isna())]
clean_laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 1   0 days 00:21:23.298000    VER           33 0 days 00:01:04.249000
# 4   0 days 00:47:02.311000    VER           33 0 days 00:01:04.208000
# 7   0 days 00:55:02.200000    VER           33 0 days 00:01:03.927000
# 10  0 days 01:08:20.560000    VER           33 0 days 00:01:03.720000
# 13  0 days 01:14:40.721000    VER           33 0 days 00:01:03.766000
# ..                     ...    ...          ...                    ...
# 285 0 days 00:25:14.633000    MSC           47 0 days 00:01:05.621000
# 288 0 days 00:32:46.856000    MSC           47 0 days 00:01:05.427000
# 291 0 days 00:18:26.899000    MAZ            9 0 days 00:01:07.106000
# 294 0 days 00:24:58.675000    MAZ            9 0 days 00:01:06.282000
# 297 0 days 00:32:23.928000    MAZ            9 0 days 00:01:05.951000
#
#      LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# ...

# %%
# show dataframe info
clean_laps.info()
# Out:
# <class 'fastf1.core.Laps'>
# Index: 124 entries, 1 to 297
# Data columns (total 38 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                124 non-null    timedelta64[ns]
#  1   Driver              124 non-null    object
#  2   DriverNumber        124 non-null    object
#  3   LapTime             124 non-null    timedelta64[ns]
#  4   LapNumber           124 non-null    float64
#  5   Stint               124 non-null    float64
#  6   PitOutTime          0 non-null      timedelta64[ns]
#  7   PitInTime           0 non-null      timedelta64[ns]
#  8   Sector1Time         124 non-null    timedelta64[ns]
#  9   Sector2Time         124 non-null    timedelta64[ns]
#  10  Sector3Time         124 non-null    timedelta64[ns]
#  11  Sector1SessionTime  124 non-null    timedelta64[ns]
#  12  Sector2SessionTime  124 non-null    timedelta64[ns]
#  13  Sector3SessionTime  124 non-null    timedelta64[ns]
# ...

# %%
# print distribution of all the columns in clean_laps
for col in clean_laps.columns:
    if clean_laps[col].dtype == 'float64':
        plt.figure(figsize=(10, 5))
        plt.hist(clean_laps[col], bins=50)
        plt.xlabel(col)
        plt.ylabel('Count')
        plt.title(f'{col} Distribution')
        plt.grid()
        plt.show()
# Out:
# /Users/hollymitchell/miniconda3/envs/mlpack_clean/lib/python3.10/site-packages/matplotlib/axes/_axes.py:7096: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /Users/hollymitchell/miniconda3/envs/mlpack_clean/lib/python3.10/site-packages/matplotlib/axes/_axes.py:7097: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 5
#       3 if clean_laps[col].dtype == 'float64':
#       4     plt.figure(figsize=(10, 5))
# ----> 5     plt.hist(clean_laps[col], bins=50)
#       6     plt.xlabel(col)
#       7     plt.ylabel('Count')
#
# File ~/miniconda3/envs/mlpack_clean/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
# ...

# %%
clean_laps.describe()
# Out:
#                             Time                    LapTime   LapNumber  \
# count                        124                        124  124.000000
# mean   0 days 00:40:12.956370967  0 days 00:01:13.778959677    8.137097
# min       0 days 00:18:26.899000     0 days 00:01:03.720000    2.000000
# 25%       0 days 00:24:48.002500     0 days 00:01:04.553750    3.750000
# 50%       0 days 00:32:44.330500     0 days 00:01:04.909500    6.500000
# 75%       0 days 00:54:54.502750     0 days 00:01:05.547500   11.250000
# max       0 days 01:16:26.699000     0 days 00:02:02.974000   23.000000
# std    0 days 00:18:44.920122337  0 days 00:00:17.895902194    5.576278
#
#             Stint PitOutTime PitInTime                Sector1Time  \
# count  124.000000          0         0                        124
# mean     2.524194        NaT       NaT  0 days 00:00:18.402612903
# min      1.000000        NaT       NaT     0 days 00:00:16.111000
# ...

# %%
# print session info
session.info
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[128], line 2
#       1 # print session info
# ----> 2 session.info()
#
# AttributeError: 'Session' object has no attribute 'info'

# %%
# plot distrubution of count of laps per driver
plt.figure(figsize=(10, 5))
plt.hist(session.laps['Driver'], bins=50)
plt.xlabel('Driver')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# fastf1.Cache.enable_cache('./f1_cache')

# years = [2018, 2019, 2020, 2021, 2022, 2023]
# race_sessions = []

# for year in years:
#     schedule = fastf1.get_event_schedule(year)
    
#     # Keep only events where the session is a Race ('R')
#     races = schedule[schedule['Session1'] == 'R']
    
#     # Append year and race name
#     for _, row in races.iterrows():
#         race_sessions.append((year, row['EventName']))

# # Print all races
# for race in race_sessions:
#     print(race)

# %%
race_sessions
# Out:
# []

# %%
# Specify the season year
year = 2023  # Change this to the desired year

# Retrieve the event schedule for the specified year
schedule = fastf1.get_event_schedule(year)

# Filter the schedule to include only race sessions
race_sessions = schedule[schedule['SessionType'] == 'R']

# Display the race sessions
print(race_sessions[['EventName', 'EventDate']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/mlpack_clean/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SessionType'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[132], line 8
# ...

# %%
schedule
# Out:
#     RoundNumber        Country           Location  \
# 0             0        Bahrain             Sakhir
# 1             1        Bahrain             Sakhir
# 2             2   Saudi Arabia             Jeddah
# 3             3      Australia          Melbourne
# 4             4     Azerbaijan               Baku
# 5             5  United States              Miami
# 6             6         Monaco             Monaco
# 7             7          Spain          Barcelona
# 8             8         Canada           Montréal
# 9             9        Austria          Spielberg
# 10           10  Great Britain        Silverstone
# 11           11        Hungary           Budapest
# 12           12        Belgium  Spa-Francorchamps
# 13           13    Netherlands          Zandvoort
# 14           14          Italy              Monza
# 15           15      Singapore         Marina Bay
# 16           16          Japan             Suzuka
# 17           17          Qatar             Lusail
# ...

# %%
# These are all the races excluding the practicing and qualifying. I need to go through the 

races = []

# list of years
years = [2021, 2022, 2023]

# for each year, get a schedule
for year in years:
    schedule = fastf1.get_event_schedule(year)
    
    # for each row, save a tuple of the year and the official event name
    for _, event in schedule.iterrows():
        # if eventformat is not conventional, skip
        if event['EventFormat'] == 'conventional':
            races.append((year, event['OfficialEventName']))

races
# Out:
# [(2021, 'FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2021'),
#  (2021,
#   "FORMULA 1 PIRELLI GRAN PREMIO DEL MADE IN ITALY E DELL'EMILIA ROMAGNA 2021"),
#  (2021, 'FORMULA 1 HEINEKEN GRANDE PRÉMIO DE PORTUGAL 2021'),
#  (2021, 'FORMULA 1 ARAMCO GRAN PREMIO DE ESPAÑA 2021'),
#  (2021, 'FORMULA 1 GRAND PRIX DE MONACO 2021'),
#  (2021, 'FORMULA 1 AZERBAIJAN GRAND PRIX 2021'),
#  (2021, 'FORMULA 1 EMIRATES GRAND PRIX DE FRANCE 2021'),
#  (2021, 'FORMULA 1 BWT GROSSER PREIS DER STEIERMARK 2021'),
#  (2021, 'FORMULA 1 BWT GROSSER PREIS VON ÖSTERREICH 2021'),
#  (2021, 'FORMULA 1 ROLEX MAGYAR NAGYDÍJ 2021'),
#  (2021, 'FORMULA 1 ROLEX BELGIAN GRAND PRIX 2021'),
#  (2021, 'FORMULA 1 HEINEKEN DUTCH GRAND PRIX 2021'),
#  (2021, 'FORMULA 1 VTB RUSSIAN GRAND PRIX 2021'),
#  (2021, 'FORMULA 1 ROLEX TURKISH GRAND PRIX 2021'),
#  (2021, 'FORMULA 1 ARAMCO UNITED STATES GRAND PRIX 2021'),
#  (2021, 'FORMULA 1 GRAN PREMIO DE LA CIUDAD DE MÉXICO 2021'),
#  (2021, 'FORMULA 1 OOREDOO QATAR GRAND PRIX 2021'),
# ...

# %%
fastf1.get_session(races[0][0], races[0][1], 'R')
# Out:
# 2021 Season Round 1: Bahrain Grand Prix - Race

# %%
# save session data into Data/[year]/[eventname].csv
import os
import tqdm

# tqdm iterate over races
for i in tqdm.tqdm(range(len(races))):
    R = races[i]
    year, event_name = R
    session = fastf1.get_session(year, event_name, 'R')
    session.load()
    
    # create directory if it doesn't exist
    if not os.path.exists(f'Data/{year}'):
        os.makedirs(f'Data/{year}')
    
    # save session data to csv
    session.laps.to_csv(f'Data/{year}/{event_name}.csv', index=False)
# load session data from csv
# Out:
#   0%|          | 0/54 [00:00<?, ?it/s]core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core        WARNING 	Driver 44 completed the race distance 00:00.067000 before the recorded end of the session.
# ...

# %%
# Load each of the data in the files and join them up

# %% [markdown]
# NEW

# %%
# Getting a list of the names of the sessions that are actually races

races = []

# list of years
years = [2018, 2019, 2020, 2021, 2022, 2023]

# for each year, get a schedule
for year in years:
    schedule = fastf1.get_event_schedule(year)
    
    # for each row, save a tuple of the year and the official event name
    for _, event in schedule.iterrows():
        # if eventformat is not conventional, skip
        if event['EventFormat'] == 'conventional':
            races.append((year, event['OfficialEventName']))

# %%
# Saving these races into folders

# save session data into Data/[year]/[eventname].csv
import os
import tqdm

event_names = []

# tqdm iterate over races
for i in tqdm.tqdm(range(len(races))):
    R = races[i]
    year, event_name = R
    try:
        session = fastf1.get_session(year, event_name, 'R')
        session.load()
    except:
        event_names.append(event_name)
    
    # create directory if it doesn't exist
    if not os.path.exists(f'Data/{year}'):
        os.makedirs(f'Data/{year}')
    
    # save session data to csv
    session.laps.to_csv(f'Data/{year}/{event_name}.csv', index=False)
for name in event_names:
    print("%s\n", name)
# load session data from csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       7 event_names = []
#       9 # tqdm iterate over races
# ---> 10 for i in tqdm.tqdm(range(len(races))):
#      11     R = races[i]
#      12     year, event_name = R
#
# NameError: name 'races' is not defined

# %%
# Joining the lap and weather data for each session

laps = session.laps.copy()
# get the weather data for each lap
weather_data = session.laps.get_weather_data()
laps = laps.reset_index(drop=True)
weather_data = weather_data.reset_index(drop=True)

# exclude the 'Time' column from weather data when joining
joined = pd.concat([laps, weather_data.loc[:, ~(weather_data.columns == 'Time')]], axis=1)
print(joined)

# %%
# Removing the laps with the pit stops and joining the weather and lap data for each session

clean_laps = joined.copy()
clean_laps = clean_laps[(clean_laps['PitOutTime'].isna()) & (clean_laps['PitInTime'].isna())]
clean_laps

# %%
import time
import os
import tqdm
import logging

# %%
# For each of the races in the Data folder, join the lap and weather data and remove the laps with pit stops. Save the new data into a new folder called Data_cleaned

cleaned_laps = []

# list of years
years = [2018, 2019, 2020, 2021, 2022, 2023]
# for each year, get a schedule

logging.getLogger('fastf1').setLevel(logging.CRITICAL)

def save_session_laps(year, event_name):
    try:
        session = fastf1.get_session(year, event_name, 'R')
        session.load()
        laps = session.laps.copy()
        weather_data = session.laps.get_weather_data()
        laps = laps.reset_index(drop=True)
        weather_data = weather_data.reset_index(drop=True)

        # exclude the 'Time' column from weather data when joining
        joined = pd.concat([laps, weather_data.loc[:, ~(weather_data.columns == 'Time')]], axis=1)
        
        # remove laps where pitouttime or pitintime is not NaT (keep undefined laps)
        clean_laps = joined.copy()
        clean_laps = clean_laps[(clean_laps['PitOutTime'].isna()) & (clean_laps['PitInTime'].isna())]
        
        # append to cleaned_laps list

        # create directory if it doesn't exist
        if not os.path.exists(f'Data_cleaned/{year}'):
            os.makedirs(f'Data_cleaned/{year}', exist_ok=True)

        # save cleaned laps
        clean_laps.to_csv(f'Data_cleaned/{year}/{event_name}.csv', index=False)
    except:
        time.sleep(10)
        print(f"Error loading session for {year} {event_name}. Retrying...")

    # session = fastf1.get_session(year, event_name, 'R')
    # session.load()
    # laps = session.laps.copy()
    # weather_data = session.laps.get_weather_data()
    # laps = laps.reset_index(drop=True)
    # weather_data = weather_data.reset_index(drop=True)

    # # exclude the 'Time' column from weather data when joining
    # joined = pd.concat([laps, weather_data.loc[:, ~(weather_data.columns == 'Time')]], axis=1)
    
    # # remove laps where pitouttime or pitintime is not NaT (keep undefined laps)
    # clean_laps = joined.copy()
    # clean_laps = clean_laps[(clean_laps['PitOutTime'].isna()) & (clean_laps['PitInTime'].isna())]
        
        # append to cleaned_laps list

    # try:
    #     session = fastf1.get_session(year, event_name, 'R')
    #     session.load()
    #     laps = session.laps.copy()
    #     return laps
    # except:
    #     print(f"Error loading session for {year} {event_name}. Retrying...")
    #     get_laps(year, event_name)

# for each year, get a schedule
# create a list to store the cleaned laps


# tqdm iterate over years
# for year in tqdm.tqdm(years):
#     # get the list of files in the Data folder for the year
#     files = os.listdir(f'Data/{year}')
#     # for each file, load the session and join the lap and weather data
#     for file in files:
#         # load the session
#         event_name = file.split('.')[0]
#         save_session_laps(year, event_name)

# %%
races = []
for year in years:
    # get the list of files in the Data folder for the year
    files = os.listdir(f'Data/{year}')
    # for each file, load the session and join the lap and weather data
    for file in files:
        event_name = file.split('.')[0]
        races.append((year, event_name))

for r in tqdm.tqdm(races[98:]):
    save_session_laps(r[0], r[1])
# Out:
# 100%|██████████| 15/15 [07:03<00:00, 28.21s/it]

# %%
# find the index of '2021 FORMULA 1 GRAND PRIX DE MONACO 2021'
for i,r in enumerate(races):
    if r[1] == 'FORMULA 1 STC SAUDI ARABIAN GRAND PRIX 2023':
        print(i)
        break
# Out:
# 98

# %%
import fastf1
fastf1.Cache.clear_cache()
